# %% [markdown]
# # Only last checkpoint

# %%
import matplotlib.pyplot as plt

# Data (excluding averages)
mse_per_seq = [
    52.36040260897104, 75.87598776147068, 98.39102316860215, 120.14814405939187,
    138.20194878635635, 152.695644577823, 164.90908127137456, 176.3994511983481,
    186.32597479762802, 195.65048548686934
]

ssim_per_frame = [
    0.8051972, 0.7604716, 0.72762644, 0.70079494, 0.6806795,
    0.66524535, 0.6524609, 0.64045924, 0.6302457, 0.6206291
]

psnr_per_frame = [
    19.114466, 17.523293, 16.392725, 15.512162, 14.897641,
    14.455559, 14.123965, 13.827261, 13.580985, 13.361341
]

lpips_per_frame = [
    0.16954026, 0.19710088, 0.21450773, 0.22699158, 0.23916881,
    0.24890575, 0.26032004, 0.27242687, 0.28289562, 0.29213637
]

frames = list(range(1, 11))

# Plotting
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle("Metrics per Frame", fontsize=16)

axs[0, 0].plot(frames, mse_per_seq, marker='o', color='blue')
axs[0, 0].set_title("MSE per Frame")
axs[0, 0].set_xlabel("Frame")
axs[0, 0].set_ylabel("MSE")
axs[0, 0].grid(True)

axs[0, 1].plot(frames, ssim_per_frame, marker='o', color='green')
axs[0, 1].set_title("SSIM per Frame")
axs[0, 1].set_xlabel("Frame")
axs[0, 1].set_ylabel("SSIM")
axs[0, 1].grid(True)

axs[1, 0].plot(frames, psnr_per_frame, marker='o', color='orange')
axs[1, 0].set_title("PSNR per Frame")
axs[1, 0].set_xlabel("Frame")
axs[1, 0].set_ylabel("PSNR (dB)")
axs[1, 0].grid(True)

axs[1, 1].plot(frames, lpips_per_frame, marker='o', color='red')
axs[1, 1].set_title("LPIPS per Frame")
axs[1, 1].set_xlabel("Frame")
axs[1, 1].set_ylabel("LPIPS")
axs[1, 1].grid(True)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
import matplotlib.pyplot as plt

iters = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

mse_per_seq = [
    1452.6491558886914,
    1610.8444799093836,
    1612.1089858702387,
    1385.413887054566,
    1398.8022180733433,
    1364.4631417209364,
    1402.3365224202473,
    1330.7721089282668,
    1381.1536455728922,
    1360.9581437168351,
]

ssim_per_frame = [
    0.5956132,
    0.61296314,
    0.6172198,
    0.6614335,
    0.6759459,
    0.6706768,
    0.68280303,
    0.7076932,
    0.6751869,
    0.688381,
]

psnr_per_frame = [
    14.75511,
    14.369817,
    14.428662,
    15.052875,
    15.052974,
    15.186094,
    15.106862,
    15.343701,
    15.224272,
    15.27894,
]

lpips_per_frame = [
    0.46518746,
    0.391644,
    0.34998986,
    0.3073902,
    0.28855723,
    0.2671979,
    0.26205987,
    0.24467897,
    0.24034135,
    0.24039939,
]

fig, axs = plt.subplots(2, 2, figsize=(12, 8), sharex=True)

axs[0, 0].plot(iters, mse_per_seq, marker='o', color='blue')
axs[0, 0].set_ylabel('MSE per seq')
axs[0, 0].set_title('MSE per sequence over iterations')
axs[0, 0].grid(True)

axs[0, 1].plot(iters, ssim_per_frame, marker='o', color='green')
axs[0, 1].set_ylabel('SSIM per frame')
axs[0, 1].set_title('SSIM per frame over iterations')
axs[0, 1].grid(True)

axs[1, 0].plot(iters, psnr_per_frame, marker='o', color='orange')
axs[1, 0].set_ylabel('PSNR per frame')
axs[1, 0].set_title('PSNR per frame over iterations')
axs[1, 0].grid(True)

axs[1, 1].plot(iters, lpips_per_frame, marker='o', color='red')
axs[1, 1].set_ylabel('LPIPS per frame')
axs[1, 1].set_title('LPIPS per frame over iterations')
axs[1, 1].set_xlabel('Iterations')
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()
