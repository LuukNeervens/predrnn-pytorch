# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Only last checkpoint (Final model metrics)

# %%
attention_mse_per_seq = [
    52.36040260897104, 75.87598776147068, 98.39102316860215, 120.14814405939187,
    138.20194878635635, 152.695644577823, 164.90908127137456, 176.3994511983481,
    186.32597479762802, 195.65048548686934
]

attention_ssim_per_frame = [
    0.8051972, 0.7604716, 0.72762644, 0.70079494, 0.6806795,
    0.66524535, 0.6524609, 0.64045924, 0.6302457, 0.6206291
]

attention_psnr_per_frame = [
    19.114466, 17.523293, 16.392725, 15.512162, 14.897641,
    14.455559, 14.123965, 13.827261, 13.580985, 13.361341
]

attention_lpips_per_frame = [
    0.16954026, 0.19710088, 0.21450773, 0.22699158, 0.23916881,
    0.24890575, 0.26032004, 0.27242687, 0.28289562, 0.29213637
]

baseline_mse_per_seq = [
    49.83746890945128, 70.6915483589632, 91.23019789117407, 110.9301803772708, 127.6862334285874,
    142.14165401841743, 154.17862241813935, 165.65447820334072, 175.11087060644923, 183.40075260759835
]

baseline_ssim_per_frame = [
    0.82856745, 0.79423726, 0.76527035, 0.7404703, 0.720803,
    0.705273, 0.6921228, 0.67908496, 0.6680762, 0.6586225
]

baseline_psnr_per_frame = [
    19.34666, 17.848246, 16.744139, 15.893031, 15.274017,
    14.803915, 14.438064, 14.108897, 13.862205, 13.661213
]

baseline_lpips_per_frame = [
    0.1567664, 0.18188165, 0.19826423, 0.2117261, 0.22371243,
    0.23498476, 0.24690263, 0.25832912, 0.2693494, 0.2796048
]


frames = list(range(1, 11))

baseline_color = 'orange'
attention_color = 'green'

# Plotting
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle("Metrics per Frame: Baseline vs Attention", fontsize=16)

# MSE
axs[0, 0].plot(frames, baseline_mse_per_seq, marker='o', color=baseline_color, label='Baseline')
axs[0, 0].plot(frames, attention_mse_per_seq, marker='o', color=attention_color, linestyle='--', label='Attention')
axs[0, 0].set_title("MSE per Frame")
axs[0, 0].set_xlabel("Frame")
axs[0, 0].set_ylabel("MSE")
axs[0, 0].grid(True)
axs[0, 0].legend()

# SSIM
axs[0, 1].plot(frames, baseline_ssim_per_frame, marker='o', color=baseline_color, label='Baseline')
axs[0, 1].plot(frames, attention_ssim_per_frame, marker='o', color=attention_color, linestyle='--', label='Attention')
axs[0, 1].set_title("SSIM per Frame")
axs[0, 1].set_xlabel("Frame")
axs[0, 1].set_ylabel("SSIM")
axs[0, 1].grid(True)
axs[0, 1].legend()

# PSNR
axs[1, 0].plot(frames, baseline_psnr_per_frame, marker='o', color=baseline_color, label='Baseline')
axs[1, 0].plot(frames, attention_psnr_per_frame, marker='o', color=attention_color, linestyle='--', label='Attention')
axs[1, 0].set_title("PSNR per Frame")
axs[1, 0].set_xlabel("Frame")
axs[1, 0].set_ylabel("PSNR (dB)")
axs[1, 0].grid(True)
axs[1, 0].legend()

# LPIPS
axs[1, 1].plot(frames, baseline_lpips_per_frame, marker='o', color=baseline_color, label='Baseline')
axs[1, 1].plot(frames, attention_lpips_per_frame, marker='o', color=attention_color, linestyle='--', label='Attention')
axs[1, 1].set_title("LPIPS per Frame")
axs[1, 1].set_xlabel("Frame")
axs[1, 1].set_ylabel("LPIPS")
axs[1, 1].grid(True)
axs[1, 1].legend()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# # Metrics over iterations

# %%
iters = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

baseline_mse_iters = [
    1520.5342778585043,
    1492.4214215259476,
    1397.1278930418941,
    1506.5604689724473,
    1377.8630929357078,
    1399.053338246173,
    1481.6856285156496,
    1563.7833497074234,
    1306.9340773126687,
    1270.8620068193918
]

baseline_ssim_iters = [
    0.5984966,
    0.60254073,
    0.65853584,
    0.6309866,
    0.68143314,
    0.67097807,
    0.66733366,
    0.67052245,
    0.71108717,
    0.72525275
]

baseline_psnr_iters = [
    14.569707,
    14.683909,
    14.981455,
    14.710739,
    15.127655,
    15.105266,
    14.918742,
    14.733473,
    15.475321,
    15.598038
]

baseline_lpips_iters = [
    0.47630304,
    0.40738305,
    0.33132872,
    0.30972004,
    0.27987045,
    0.2680868,
    0.25823337,
    0.26272526,
    0.23359413,
    0.22615214
]

attention_mse_iters = [
    1452.6491558886914,
    1610.8444799093836,
    1612.1089858702387,
    1385.413887054566,
    1398.8022180733433,
    1364.4631417209364,
    1402.3365224202473,
    1330.7721089282668,
    1381.1536455728922,
    1360.9581437168351
]

attention_ssim_iters = [
    0.5956132,
    0.61296314,
    0.6172198,
    0.6614335,
    0.6759459,
    0.6706768,
    0.68280303,
    0.7076932,
    0.6751869,
    0.688381
]

attention_psnr_iters = [
    14.75511,
    14.369817,
    14.428662,
    15.052875,
    15.052974,
    15.186094,
    15.106862,
    15.343701,
    15.224272,
    15.27894
]

attention_lpips_iters = [
    0.46518746,
    0.391644,
    0.34998986,
    0.3073902,
    0.28855723,
    0.2671979,
    0.26205987,
    0.24467897,
    0.24034135,
    0.24039939
]


# Plotting
fig, axs = plt.subplots(2, 2, figsize=(12, 8), sharex=False)

# MSE
axs[0, 0].plot(iters, baseline_mse_iters, marker='o', label='Baseline', color=baseline_color)
axs[0, 0].plot(iters, attention_mse_iters, marker='o', label='Attention', linestyle='--', color=attention_color)
axs[0, 0].set_ylabel('MSE per seq')
axs[0, 0].set_xlabel('Iterations')
axs[0, 0].set_title('MSE over iterations')
axs[0, 0].grid(True)
axs[0, 0].legend()

# SSIM
axs[0, 1].plot(iters, baseline_ssim_iters, marker='o', label='Baseline', color=baseline_color)
axs[0, 1].plot(iters, attention_ssim_iters, marker='o', label='Attention', linestyle='--',  color=attention_color)
axs[0, 1].set_ylabel('SSIM per frame')
axs[0, 1].set_xlabel('Iterations')
axs[0, 1].set_title('SSIM over iterations')
axs[0, 1].grid(True)
axs[0, 1].legend()

# PSNR
axs[1, 0].plot(iters, baseline_psnr_iters, marker='o', label='Baseline', color=baseline_color)
axs[1, 0].plot(iters, attention_psnr_iters, marker='o', label='Attention', linestyle='--', color=attention_color)
axs[1, 0].set_ylabel('PSNR per frame')
axs[1, 0].set_xlabel('Iterations')
axs[1, 0].set_title('PSNR over iterations')
axs[1, 0].grid(True)
axs[1, 0].legend()

# LPIPS
axs[1, 1].plot(iters, baseline_lpips_iters, marker='o', label='Baseline', color=baseline_color)
axs[1, 1].plot(iters, attention_lpips_iters, marker='o', label='Attention', linestyle='--', color=attention_color)
axs[1, 1].set_ylabel('LPIPS per frame')
axs[1, 1].set_title('LPIPS over iterations')
axs[1, 1].set_xlabel('Iterations')
axs[1, 1].grid(True)
axs[1, 1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Trainig Losses

# %%
# Iterations
iters = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

# Attention model training losses
attention_train_losses = [
    0.0225983839482069,
    0.022090639919042587,
    0.019568488001823425,
    0.01709161326289177,
    0.016673248261213303,
    0.01581849530339241,
    0.014469556510448456,
    0.013374652713537216,
    0.01635356992483139,
    0.01401958242058754
]

# Baseline model training losses
baseline_train_losses = [
    0.022759683,
    0.024227472,
    0.020682184,
    0.016952671,
    0.016706865,
    0.013974136,
    0.017034221,
    0.015359477,
    0.016226266,
    0.013133744
]

# Plotting
plt.figure(figsize=(8, 5))
plt.plot(iters, attention_train_losses, marker='o', color=attention_color, label='Attention Training Loss')
plt.plot(iters, baseline_train_losses, marker='o', color=baseline_color, label='Baseline Training Loss')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Training Loss over Iterations')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
